# %%
# !pip install line-bot-sdk
# !pip install requests
# Out:
# Requirement already satisfied: line-bot-sdk in /opt/anaconda3/lib/python3.7/site-packages (1.18.0)
# Requirement already satisfied: requests>=2.0 in /opt/anaconda3/lib/python3.7/site-packages (from line-bot-sdk) (2.22.0)
# Requirement already satisfied: future in /opt/anaconda3/lib/python3.7/site-packages (from line-bot-sdk) (0.17.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.7/site-packages (from requests>=2.0->line-bot-sdk) (2019.9.11)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/anaconda3/lib/python3.7/site-packages (from requests>=2.0->line-bot-sdk) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/anaconda3/lib/python3.7/site-packages (from requests>=2.0->line-bot-sdk) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/anaconda3/lib/python3.7/site-packages (from requests>=2.0->line-bot-sdk) (1.24.2)
# WARNING: You are using pip version 20.3.1; however, version 20.3.3 is available.
# You should consider upgrading via the '/opt/anaconda3/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.7/site-packages (2.22.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/anaconda3/lib/python3.7/site-packages (from requests) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/anaconda3/lib/python3.7/site-packages (from requests) (1.24.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.7/site-packages (from requests) (2019.9.11)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/anaconda3/lib/python3.7/site-packages (from requests) (2.8)
# WARNING: You are using pip version 20.3.1; however, version 20.3.3 is available.
# You should consider upgrading via the '/opt/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
import json
import requests

# %%
file = open('info.json','r')

# %%
info = json.load(file)

# %%
info
# Out:
# {'CHANNEL_ACCESS_TOKEN': 'RK7yHgGox1O97x0ujqp/ZBUzHKgYGxMSFc5a+a55DXr6KdNqJN1ZxMdHXGFw/B03R6QimNqZdM4U4m/agP262nqYeU/xJ4VdRV7uW/87RchKBeSnZU5CD7yrDR1seZUfC5zna4HeKbMFuxvZ8bed5AdB04t89/1O/w1cDnyilFU=',
#  'USER_ID': 'U661a936041e25413afd968640a25f1e9'}

# %%
#LINE BOT作成
from linebot import LineBotApi
from linebot.models import TextSendMessage

# %%
CHANNEL_ACCESS_TOKEN = info['CHANNEL_ACCESS_TOKEN']
line_bot_api = LineBotApi(CHANNEL_ACCESS_TOKEN)

# %%
data = requests.get('https://note.com/api/v2/notes')

# %%
data.json()
# Out:
# {'data': {'contents': [{'id': 17763347,
#     'type': 'TextNote',
#     'status': 'published',
#     'name': '今週末の日曜日、ユニクロで白T買って泣く',
#     'description': None,
#     'price': 0,
#     'key': 'nfe51e6e81c25',
#     'slug': 'slug-nfe51e6e81c25',
#     'publishAt': '2020/07/01 21:20',
#     'thumbnailExternalUrl': '',
#     'eyecatch': 'https://assets.st-note.com/production/uploads/images/29446738/square_large_5cb67294834051ed8fb7c3f113ea4dd3.png',
#     'user': {'id': 720952,
#      'name': '島田彩',
#      'urlname': 'cchan1110',
#      'nickname': '島田彩',
#      'userProfileImagePath': 'https://assets.st-note.com/production/uploads/images/27192276/profile_631c9ba68174e12170095f0fee1fc3e8.jpg?fit=bounds&format=jpeg&quality=45&width=330',
#      'customDomain': None,
#      'disableSupport': False,
#      'likeAppealText': '「スキ」ってすごく嬉しい',
#      'likeAppealImage': 'https://assets.st-note.com/production/uploads/images/34887138/c056234fdd3156b3b5bfc95a9fdef7ad.jpeg?fit=bounds&format=jpeg&height=500&quality=45&width=500',
#      'purchaseAppealTextNote': None,
#      'twitterNickname': 'c_chan1110'},
#     'canRead': True,
#     'isAuthor': False,
#     'externalUrl': None,
#     'customDomain': None,
#     'body': '今週末の日曜日、私はユニクロで泣く。\n\nいつも行く、イオンの4階に入っているユニクロで。きっと、震えながら白のエアリズムコットンオーバーサイズTシャツ（5分袖）を手に取って、泣く。\n\n何の話か全くわからないと思うけど、今、たった今3時間前に起きたことを、心臓をばくばくさせながら、今日は書く。\n\n私の家は、奈良にある。近鉄電車の快速急行が止まる駅。そして、家の94％を、地元の20代以下に開放している。(6%は私の寝室)（その話はまたいつか…）\n\nその中で、最近よく遊びにくる18',
#     'separator': None,
#     'isLimited': False,
#     'isTrial': False,
#     'canUpdate': False,
#     'tweetText': '今週末の日曜日、ユニクロで白T買って泣く｜島田彩 @c_chan1110 #note',
#     'additionalAttr': {'anonymousLikeCount': 21596},
#     'isRefund': False,
#     'likeCount': 34956},
#    {'id': 24153580,
#     'type': 'TextNote',
#     'status': 'published',
#     'name': '全財産を使って外車買ったら、えらいことになった',
#     'description': None,
#     'price': 0,
#     'key': 'nc5c2d1607f45',
#     'slug': 'slug-nc5c2d1607f45',
#     'publishAt': '2020/12/02 14:35',
#     'thumbnailExternalUrl': '',
#     'eyecatch': 'https://assets.st-note.com/production/uploads/images/40003626/square_large_393d94568195cc1c43868de4dd1df411.jpg',
#     'user': {'id': 37700,
#      'name': '岸田 奈美',
#      'urlname': 'namirairo',
#      'nickname': '岸田 奈美',
#      'userProfileImagePath': 'https://assets.st-note.com/production/uploads/images/20344937/profile_09f8936fddfdd10137af211499a16fe3.jpg?fit=bounds&format=jpeg&quality=45&width=330',
#      'customDomain': {'id': 647,
#       'tls': True,
#       'host': 'note.kishidanami.com',
#       'type': 'creator',
#       'key': 'namirairo'},
#      'disableSupport': False,
#      'likeAppealText': 'ノーマル大吉！普通が一番ってね！',
#      'likeAppealImage': None,
#      'purchaseAppealTextNote': None,
#      'twitterNickname': 'namikishida'},
#     'canRead': True,
#     'isAuthor': False,
#     'externalUrl': None,
#     'customDomain': {'id': 647,
#      'tls': True,
#      'host': 'note.kishidanami.com',
#      'type': 'creator',
#      'key': 'namirairo'},
#     'body': '12月19日 追記\nこちらの記事が、とんでもねえ経緯と熱量で、英語ほか10言語に翻訳されました！\n英語翻訳された奇跡の舞台裏note\n英語翻訳版の記事\n\n全財産の内訳は、大学生の時からベンチャー企業で10年間働いて、したたり落ちるスズメの涙を貯め込んだお金と。\n\nこんなもん、もう一生書けへんわと思うくらいの熱量を打ち込んで書いた本の印税だ。\n\nそれらが一瞬にして、なくなった。\n\n外車を買ったからだ。\n運転免許もないのに。\n\n「調子乗ってんなよお前」と思った人も、「どうせ“わた',
#     'separator': None,
#     'isLimited': False,
#     'isTrial': False,
#     'canUpdate': False,
#     'tweetText': '全財産を使って外車買ったら、えらいことになった｜岸田 奈美 @namikishida #note',
#     'additionalAttr': {'anonymousLikeCount': 18700},
#     'isRefund': False,
#     'likeCount': 30303},
#    {'id': 11305045,
#     'type': 'TextNote',
#     'status': 'published',
#     'name': '100日間おなじ商品を買い続けることでコンビニ店員からあだ名をつけられるか。',
#     'description': None,
#     'price': 0,
#     'key': 'n773f51e01077',
#     'slug': 'slug-n773f51e01077',
#     'publishAt': '2020/01/19 21:41',
#     'thumbnailExternalUrl': '',
#     'eyecatch': None,
#     'user': {'id': 1755289,
#      'name': 'yosano',
#      'urlname': 'mutekiinc',
#      'nickname': 'yosano',
#      'userProfileImagePath': 'https://assets.st-note.com/production/uploads/images/25627398/profile_f35c077b1e5ec2105bc8f2b2e14fa6a5.jpg?fit=bounds&format=jpeg&quality=45&width=330',
#      'customDomain': None,
#      'disableSupport': False,
#      'likeAppealText': '7月15日 近くのスーパーで普段着の副店長と遭遇してビックリしました',
#      'likeAppealImage': None,
#      'purchaseAppealTextNote': None,
#      'twitterNickname': None},
#     'canRead': True,
#     'isAuthor': False,
#     'externalUrl': None,
#     'customDomain': None,
#     'body': 'はじめに\n\nコンビニ\u3000便利ですよね。\n\nお弁当\u3000飲みもの\u3000おかし\u3000雑誌\u3000タバコ\u3000お酒\u3000日用品。必要なものはコンビニに行けばだいたい売っています。昼食やコーヒーを買うために毎日同じコンビニで買い物するという人もたくさんいるでしょう。もはやコンビニで買い物することは現代人にとって生活の一部といえますね。\n\nただ、毎日おなじものを買っていることで「店員さんにあだ名を付けられているのではないか」と不安になったことはありませんか？\n\n100日間おなじ商品を買い続けることでコンビニ店員か',
#     'separator': None,
#     'isLimited': False,
#     'isTrial': False,
#     'canUpdate': False,
#     'tweetText': '100日間おなじ商品を買い続けることでコンビニ店員からあだ名をつけられるか。｜yosano #note',
#     'additionalAttr': {'anonymousLikeCount': 20384},
#     'isRefund': False,
#     'likeCount': 29258},
#    {'id': 13861291,
#     'type': 'TextNote',
#     'status': 'published',
#     'name': '医療の現場から',
#     'description': None,
#     'price': 0,
#     'key': 'na4fb2c05ff55',
#     'slug': 'slug-na4fb2c05ff55',
#     'publishAt': '2020/04/09 16:26',
#     'thumbnailExternalUrl': '',
#     'eyecatch': None,
#     'user': {'id': 2296380,
#      'name': '四谷三丁目',
#      'urlname': 'yo_tsu_ya_3',
#      'nickname': '四谷三丁目',
#      'userProfileImagePath': 'https://d2l930y2yx77uc.cloudfront.net/assets/default/default_profile_1-656d3225280a5a1fd3b6161788b209aa56e12aaf64c1ac73e6d0f7ea0b2afadd.png',
#      'customDomain': None,
#      'disableSupport': False,
#      'likeAppealText': None,
#      'likeAppealImage': None,
#      'purchaseAppealTextNote': None,
#      'twitterNickname': None},
#     'canRead': True,
#     'isAuthor': False,
#     'externalUrl': None,
#     'customDomain': None,
#     'body': '頭がおかしくなりそうなのでしたためておく。\n私は医療職に従事している人間である。看護師だ。\n専門職ではあるものの、この歴史に刻まれるであろう混乱の中で私の有する専門性や経験値など紙切れ以下の価値もない。現状、私は「たまたま医療職に従事している一般人」であり、これは専門性を有する人間からの警告などではなく、ただならぬ混乱に巻き込まれた一般人の雄叫びである。\nそのように受け止めてほしい。\n\n私が勤めているのは首都圏の「けっこう大きな病院」である。今回の新型コロナウイルス感染症騒動',
#     'separator': None,
#     'isLimited': False,
#     'isTrial': False,
#     'canUpdate': False,
#     'tweetText': '医療の現場から｜四谷三丁目 #note',
#     'additionalAttr': {'anonymousLikeCount': 21871},
#     'isRefund': False,
#     'likeCount': 26768},
#    {'id': 9127310,
#     'type': 'TextNote',
#     'status': 'published',
#     'name': '弟が万引きを疑われ、そして母は赤べこになった',
#     'description': None,
#     'price': 0,
#     'key': 'n28c8d62e0eee',
#     'slug': 'slug-n28c8d62e0eee',
#     'publishAt': '2019/09/30 20:50',
#     'thumbnailExternalUrl': '',
#     'eyecatch': 'https://assets.st-note.com/production/uploads/images/14778995/square_large_6ab85af1283257792b896380d5c265d1.jpeg',
#     'user': {'id': 37700,
#      'name': '岸田 奈美',
#      'urlname': 'namirairo',
#      'nickname': '岸田 奈美',
#      'userProfileImagePath': 'https://assets.st-note.com/production/uploads/images/20344937/profile_09f8936fddfdd10137af211499a16fe3.jpg?fit=bounds&format=jpeg&quality=45&width=330',
#      'customDomain': {'id': 647,
#       'tls': True,
#       'host': 'note.kishidanami.com',
#       'type': 'creator',
#       'key': 'namirairo'},
#      'disableSupport': False,
#      'likeAppealText': 'ミラクル優勝大吉！胴上げしていい？',
#      'likeAppealImage': None,
#      'purchaseAppealTextNote': None,
#      'twitterNickname': 'namikishida'},
#     'canRead': True,
#     'isAuthor': False,
#     'externalUrl': None,
#     'customDomain': {'id': 647,
#      'tls': True,
#      'host': 'note.kishidanami.com',
#      'type': 'creator',
#      'key': 'namirairo'},
#     'body': '高校から帰ったら、母が大騒ぎしていた。\nなんだなんだ、一体どうした。\n\n「良太が万引きしたかも」\n\n良太とは、私の３歳下の弟だ。\n\n生まれつき、ダウン症という病気で、知的障害がある。\n大人になった今も、良太の知能レベルは2歳児と同じだ。\n\nヒトの細胞の染色体が一本多いと、ダウン症になるらしい。\n一本得してるはずなのに、不思議ね。\n\n「良太が万引き？あるわけないやろ」\n\nヒヤリハットを、そういう帽子だと思っていた母のことなので。\n\n「ちゃうねん！あるんやて！」\n\nニコラスケイジ',
#     'separator': None,
#     'isLimited': False,
#     'isTrial': False,
#     'canUpdate': False,
#     'tweetText': '弟が万引きを疑われ、そして母は赤べこになった｜岸田 奈美 @namikishida #note #こんな社会だったらいいな',
#     'additionalAttr': {'anonymousLikeCount': 13745},
#     'isRefund': False,
#     'likeCount': 22969},
#    {'id': 16765857,
#     'type': 'TextNote',
#     'status': 'published',
#     'name': 'この割れ切った世界の片隅で',
#     'description': None,
#     'price': 0,
#     'key': 'nba61eb70085a',
#     'slug': 'slug-nba61eb70085a',
#     'publishAt': '2020/06/08 00:21',
#     'thumbnailExternalUrl': '',
#     'eyecatch': 'https://assets.st-note.com/production/uploads/images/27745867/square_large_26640922aaf057ca3d42d8b61580bd73.jpeg',
#     'user': {'id': 873520,
#      'name': '鈴',
#      'urlname': '__carpediem___',
#      'nickname': '鈴',
#      'userProfileImagePath': 'https://assets.st-note.com/production/uploads/images/32449355/profile_df783f7e9f8856e7f575243097fa1c04.png?fit=bounds&format=jpeg&quality=45&width=330',
#      'customDomain': None,
#      'disableSupport': False,
#      'likeAppealText': 'ありがとうございます！よろしければ感想も頂ければ嬉しいです！♡',
#      'likeAppealImage': None,
#      'purchaseAppealTextNote': None,
#      'twitterNickname': 'carpediem_530'},
#     'canRead': True,
#     'isAuthor': False,
#     'externalUrl': None,
#     'customDomain': None,
#     'body': 'コロナウイルスが社会に与えた最も大きな影響は、見えづらかった社会の分断を可視化したことではないでしょうか。\n\nステイホームできない、明日を生きるのすら精一杯な人。パソコンを持っておらず、家では完全に社会から隔離されてしまう人。勉強ができるような家庭環境でない人。外で遊ぶ自分を自慢げにSNSに載せる人。「クラスターフェス」と称し、コロナに積極的にかかろうとする人。感染者を引っ越しにまで追い込む地方の村社会。\n\n普段暮らしているとそのような人と出会わない、という人が殆どでしょう。',
#     'separator': None,
#     'isLimited': False,
#     'isTrial': False,
#     'canUpdate': False,
#     'tweetText': 'この割れ切った世界の片隅で｜鈴 @carpediem_530 #note #ゆたかさって何だろう',
#     'additionalAttr': {'anonymousLikeCount': 12872},
#     'isRefund': False,
#     'likeCount': 22621},
#    {'id': 14938448,
#     'type': 'TextNote',
#     'status': 'published',
#     'name': 'はじめまして、菊地です。',
#     'description': None,
#     'price': 0,
#     'key': 'naf59184a278a',
#     'slug': 'slug-naf59184a278a',
#     'publishAt': '2020/05/02 20:05',
#     'thumbnailExternalUrl': '',
#     'eyecatch': 'https://assets.st-note.com/production/uploads/images/24535854/square_large_b4c0e50aae950ff2e53f9f0d2d29ca0c.jpg',
#     'user': {'id': 2813483,
#      'name': '株式会社STPR',
#      'urlname': 'stpr',
#      'nickname': '株式会社STPR',
#      'userProfileImagePath': 'https://assets.st-note.com/production/uploads/images/28264468/profile_4717624ff99ea691533a916772bbdf03.jpg?fit=bounds&format=jpeg&quality=45&width=330',
#      'customDomain': None,
#      'disableSupport': True,
#      'likeAppealText': None,
#      'likeAppealImage': None,
#      'purchaseAppealTextNote': None,
#      'twitterNickname': None},
#     'canRead': True,
#     'isAuthor': False,
#     'externalUrl': None,
#     'customDomain': None,
#     'body': 'みなさん、はじめまして。\n株式会社STPRで「すとぷり」の活動をお手伝いしている菊地と申します。\n\n今はコロナウィルスの影響もあり、おうちでお仕事をしています。\nせっかくですのでこの機会を活かして、会社がなにをしているのかを伝えるために「ブログ」を始めてみようと思いました。\n\nななもり。さん（今は、私にとっては社長になりますが…）が、私が暇そうだ…みたいなことを配信で言っていたのもちゃんと見ています…。\n\n全くそんなことはありません…。\nななもり。さんから、いつも突然、予想外',
#     'separator': None,
#     'isLimited': False,
#     'isTrial': False,
#     'canUpdate': False,
#     'tweetText': 'はじめまして、菊地です。｜株式会社STPR #note',
#     'additionalAttr': {'anonymousLikeCount': 14356},
#     'isRefund': False,
#     'likeCount': 17668},
#    {'id': 20783835,
#     'type': 'TextNote',
#     'status': 'published',
#     'name': '釧路珍道中〜Peachまさかの緊急着陸',
#     'description': None,
#     'price': 0,
#     'key': 'n469cc6f7c017',
#     'slug': 'slug-n469cc6f7c017',
#     'publishAt': '2020/09/11 12:19',
#     'thumbnailExternalUrl': '',
#     'eyecatch': 'https://assets.st-note.com/production/uploads/images/34426751/square_large_7572679d48ebc99730ce74d86acb34a5.jpeg',
#     'user': {'id': 3595310,
#      'name': 'かずま',
#      'urlname': 'livekazuma',
#      'nickname': 'かずま',
#      'userProfileImagePath': 'https://assets.st-note.com/production/uploads/images/34434441/profile_6b3574074f4e643d1c1840306c3d1ca7.jpeg?fit=bounds&format=jpeg&quality=45&width=330',
#      'customDomain': None,
#      'disableSupport': False,
#      'likeAppealText': '小吉',
#      'likeAppealImage': None,
#      'purchaseAppealTextNote': None,
#      'twitterNickname': None},
#     'canRead': True,
#     'isAuthor': False,
#     'externalUrl': None,
#     'customDomain': None,
#     'body': '釧路旅行に行ってきました。\n\nまさか旅程がニュースになるなんて思わなかった。\n\nせめてネタにしたい。2時間半分のネタにはしたい。あと願わくば同じような事はもう二度と起きませんように、という気持ちも込めて。\n\n大型で記録史上最凶などと噂される台風が近づく中、9/5関空からPeachでたんちょう釧路空港まで行ってまいりました。\n\n幸いにも関西から北海道は直撃も避けたようなので予定通り二泊三日。\n\n炉端焼き食べたり\n\nスパカツ食べたり\n\nエスカロップ食べたり\n\n花咲蟹ラーメン食べた',
#     'separator': None,
#     'isLimited': False,
#     'isTrial': False,
#     'canUpdate': False,
#     'tweetText': '釧路珍道中〜Peachまさかの緊急着陸｜かずま #note',
#     'additionalAttr': {'anonymousLikeCount': 12528},
#     'isRefund': False,
#     'likeCount': 16187},
#    {'id': 14529810,
#     'type': 'TextNote',
#     'status': 'published',
#     'name': '【1時間で分かる】P&G流マーケティングの教科書',
#     'description': None,
#     'price': 0,
#     'key': 'na578fec5ef84',
#     'slug': 'slug-na578fec5ef84',
#     'publishAt': '2020/07/07 20:20',
#     'thumbnailExternalUrl': '',
#     'eyecatch': None,
#     'user': {'id': 2247939,
#      'name': '石井賢介（Marketing Demo代表取締役）',
#      'urlname': '141ishii',
#      'nickname': '石井賢介（Marketing Demo代表取締役）',
#      'userProfileImagePath': 'https://assets.st-note.com/production/uploads/images/32021875/profile_9bfd0d34619a4b3da71ce2279316eaa1.png?fit=bounds&format=jpeg&quality=45&width=330',
#      'customDomain': None,
#      'disableSupport': False,
#      'likeAppealText': None,
#      'likeAppealImage': None,
#      'purchaseAppealTextNote': None,
#      'twitterNickname': 'IshiiKensuke'},
#     'canRead': True,
#     'isAuthor': False,
#     'externalUrl': None,
#     'customDomain': None,
#     'body': '2020年5月末でP&Gのブランドマネージャーを退職しました。僕はこのNOTEで、P&Gで非言語的に受け継がれているマーケティングの思考法を、分かりやすい教科書のようにまとめようと思います。本気で読めば1時間かからず読めると思います。が、ちゃんと理解すれば知識レベルとしては本何冊分にもなることをお約束します。さらには、そのマーケティング思考の先に、僕がどんなマーケティングの進化を考えていて、そのために次のチャレンジとしてどんなアクションを取ろうと思っているかも最終章にまとめよ',
#     'separator': None,
#     'isLimited': False,
#     'isTrial': False,
#     'canUpdate': False,
#     'tweetText': '【1時間で分かる】P&G流マーケティングの教科書｜石井賢介（Marketing Demo代表取締役） @IshiiKensuke #note #社会人1年目の私へ',
#     'additionalAttr': {'anonymousLikeCount': 5645,
#      'index': [{'name': 'zjeKo', 'body': '1. 優れたブランドに共通するたった一つの秘密とは？'},
#       {'name': 'nK7FK', 'body': '2. 戦略の重要性を理解せよ！'},
#       {'name': 'dgZ3V', 'body': '3．戦略の基本型を把握せよ！'},
#       {'name': 'ptMhp', 'body': '4.\u3000WHO(フー)ではなく、”不(フ)”が大事！'},
#       {'name': 'cqSsD', 'body': '5.\u3000ブランドは何を(WHAT)売っているのか？POD編'},
#       {'name': 'C4nt3', 'body': '6.\u3000ブランドは何を(WHAT)売っているのか？コミュニケーション編'},
#       {'name': '343Ij', 'body': '7.\u3000冷静に計画し、情熱的な実行(HOW)で勝つ！'},
#       {'name': 'y9SpU', 'body': '8.\u3000最後に\u3000僕はマーケティングを進化させたい！'}]},
#     'isRefund': False,
#     'likeCount': 15390},
#    {'id': 16434320,
#     'type': 'TextNote',
#     'status': 'published',
#     'name': '小学1年生ぶりに、父の前で真っ裸になった話',
#     'description': None,
#     'price': 0,
#     'key': 'n28e4846db8d6',
#     'slug': 'slug-n28e4846db8d6',
#     'publishAt': '2020/05/31 23:51',
#     'thumbnailExternalUrl': '',
#     'eyecatch': 'https://assets.st-note.com/production/uploads/images/27175449/square_large_5e256f3b353a1fe2a18cde1bc3dbd706.jpeg',
#     'user': {'id': 720952,
#      'name': '島田彩',
#      'urlname': 'cchan1110',
#      'nickname': '島田彩',
#      'userProfileImagePath': 'https://assets.st-note.com/production/uploads/images/27192276/profile_631c9ba68174e12170095f0fee1fc3e8.jpg?fit=bounds&format=jpeg&quality=45&width=330',
#      'customDomain': None,
#      'disableSupport': False,
#      'likeAppealText': '最近ハマってる食べ物は「パラタ」です',
#      'likeAppealImage': 'https://assets.st-note.com/production/uploads/images/33857650/37b9394a50c3ae256c7d557c58689e35.jpg?fit=bounds&format=jpeg&height=500&quality=45&width=500',
#      'purchaseAppealTextNote': None,
#      'twitterNickname': 'c_chan1110'},
#     'canRead': True,
#     'isAuthor': False,
#     'externalUrl': None,
#     'customDomain': None,
#     'body': '「お父さん、ヌードを撮ってくれませんか。」\xa0\n\nもうすぐ30歳になる私が、父に送ったLINE。\n\n「何言ってんだお前、女友達に撮ってもらいなさい！」\nそう来るかなと思ったけど、返事はすぐに届いた。\n\n「了解！前日、下着の跡形つかないように！」 \n\n正直、「父親」や「夫」としてはあまり自慢できないけれど、「人」としてはすごく面白い。そんな父の前で、小学1年生ぶりに真っ裸になり、ヌードを撮ってもらったという話です。父が最近あんまり元気ないので、この機会に、父との物語を綴ろうと思い',
#     'separator': None,
#     'isLimited': False,
#     'isTrial': False,
#     'canUpdate': False,
#     'tweetText': '小学1年生ぶりに、父の前で真っ裸になった話｜島田彩 @c_chan1110 #note',
#     'additionalAttr': {'anonymousLikeCount': 8279},
#     'isRefund': False,
#     'likeCount': 14728},
#    {'id': 15180547,
#     'type': 'TextNote',
#     'status': 'published',
#     'name': '全店舗閉店して会社を清算することに決めました',
#     'description': None,
#     'price': 0,
#     'key': 'nd4264eabe912',
#     'slug': 'slug-nd4264eabe912',
#     'publishAt': '2020/05/08 13:12',
#     'thumbnailExternalUrl': '',
#     'eyecatch': 'https://assets.st-note.com/production/uploads/images/25105293/square_large_7a2b15b7c4348e5a2452a3576466e892.jpg',
#     'user': {'id': 39712,
#      'name': '福井寿和@倒産を経験した社長',
#      'urlname': 'aomorio',
#      'nickname': '福井寿和@倒産を経験した社長',
#      'userProfileImagePath': 'https://assets.st-note.com/production/uploads/images/132942/profile_5ac3ef53468c63c104214a9102d5c04f.jpg?fit=bounds&format=jpeg&quality=45&width=330',
#      'customDomain': None,
#      'disableSupport': False,
#      'likeAppealText': 'スキありがとうございます！',
#      'likeAppealImage': None,
#      'purchaseAppealTextNote': '購入ありがとうございます！質問などありましたらお気軽にご連絡くださいね！',
#      'twitterNickname': 'aomorio'},
#     'canRead': True,
#     'isAuthor': False,
#     'externalUrl': None,
#     'customDomain': None,
#     'body': '＼＼\u3000出版が決まりました\u3000／／\n\n私が起業したきっかけ、カフェの開業、事業拡大、そして全店舗閉店して会社を精算するまでの全て書いた本の出版が決定しました！\n\n2020年11月2日発売\n『全店舗閉店して会社を清算することにしました\u3000コロナで全店舗閉店、事業清算、再出発を選んだ社長の話』（実業之日本社）\n\nAmazonで販売中です！\nhttps://amzn.to/3mLughG\n\n※写真はお店を片付けた時に従業員と記念に撮ったものです。\n\nこんにちは。東北地方でカフェなど飲食店',
#     'separator': None,
#     'isLimited': False,
#     'isTrial': False,
#     'canUpdate': False,
#     'tweetText': '全店舗閉店して会社を清算することに決めました｜福井寿和@倒産を経験した社長 @aomorio #note',
#     'additionalAttr': {'anonymousLikeCount': 8087},
#     'isRefund': False,
#     'likeCount': 13793},
#    {'id': 10456515,
#     'type': 'TextNote',
#     'status': 'published',
#     'name': '待ち焦がれていた、いとしの『サザンオールスターズ』サブスク解禁🔓㊗ LINE MUSICで全曲聴き放題に！🌊',
#     'description': None,
#     'price': 0,
#     'key': 'n1a9f7c74cc5c',
#     'slug': 'slug-n1a9f7c74cc5c',
#     'publishAt': '2019/12/20 00:31',
#     'thumbnailExternalUrl': '',
#     'eyecatch': 'https://assets.st-note.com/production/uploads/images/16816543/square_large_a6d5e2356590568d1b290f98eff51751.jpeg',
#     'user': {'id': 1578556,
#      'name': 'LINE MUSIC（ラインミュージック）',
#      'urlname': 'linemusic',
#      'nickname': 'LINE MUSIC（ラインミュージック）',
#      'userProfileImagePath': 'https://assets.st-note.com/production/uploads/images/13145023/profile_95048857813f04ec60da37a9e15c47e2.jpg?fit=bounds&format=jpeg&quality=45&width=330',
#      'customDomain': {'id': 400,
#       'tls': True,
#       'host': 'note.linemusic.jp',
#       'type': 'creator',
#       'key': 'linemusic'},
#      'disableSupport': True,
#      'likeAppealText': 'ぺこり♡',
#      'likeAppealImage': None,
#      'purchaseAppealTextNote': None,
#      'twitterNickname': 'LINEMUSIC_JP'},
#     'canRead': True,
#     'isAuthor': False,
#     'externalUrl': None,
#     'customDomain': {'id': 400,
#      'tls': True,
#      'host': 'note.linemusic.jp',
#      'type': 'creator',
#      'key': 'linemusic'},
#     'body': '今年の夏、いったい私は何度サザンオールスターズの楽曲を再生したことでしょう。\n\n夏の代名詞である "サザン" の曲を聴きさえすれば、寒さで凍える冬だって、"あの夏" の匂い・景色・交わした言葉が急速によみがえり、たちまち脳内がサザン色に染まって温かくなります。\n\nさて、先から「夏。夏。」と繰り返しましたが、\nサザンオールスターズの楽曲は夏に限らず、今の時期にぴったりな冬ソングだってあるのです。\n\nひとまず、サザンオールスターズの定番曲をいくつかピックアックしたので、そちらをご',
#     'separator': None,
#     'isLimited': False,
#     'isTrial': False,
#     'canUpdate': False,
#     'tweetText': '待ち焦がれていた、いとしの『サザンオールスターズ』サブスク解禁🔓㊗ LINE MUSICで全曲聴き放題に！🌊｜LINE MUSIC（ラインミュージック） @LINEMUSIC_JP #note',
#     'additionalAttr': {'anonymousLikeCount': 13210,
#      'index': [{'name': 'AIT99', 'body': '🏆サザンオールスターズ定番曲👑'},
#       {'name': 'ymEMa', 'body': '気になるサザンの最新曲もぜひ聴いてほしい'},
#       {'name': '532t0', 'body': '桑田佳祐のソロ曲も聴ける！？！？'}]},
#     'isRefund': False,
#     'likeCount': 13304},
#    {'id': 14968707,
#     'type': 'TextNote',
#     'status': 'published',
#     'name': 'あらためまして、菊「地」です。',
#     'description': None,
#     'price': 0,
#     'key': 'nd954f45fb489',
#     'slug': 'slug-nd954f45fb489',
#     'publishAt': '2020/05/03 21:09',
#     'thumbnailExternalUrl': '',
#     'eyecatch': 'https://assets.st-note.com/production/uploads/images/24590576/square_large_86c0ef5bce37dbbefc79e755e65a8c88.jpg',
#     'user': {'id': 2813483,
#      'name': '株式会社STPR',
#      'urlname': 'stpr',
#      'nickname': '株式会社STPR',
#      'userProfileImagePath': 'https://assets.st-note.com/production/uploads/images/28264468/profile_4717624ff99ea691533a916772bbdf03.jpg?fit=bounds&format=jpeg&quality=45&width=330',
#      'customDomain': None,
#      'disableSupport': True,
#      'likeAppealText': None,
#      'likeAppealImage': None,
#      'purchaseAppealTextNote': None,
#      'twitterNickname': None},
#     'canRead': True,
#     'isAuthor': False,
#     'externalUrl': None,
#     'customDomain': None,
#     'body': 'みなさん、こんばんは。\n株式会社STPRの菊地です。\n\nすとぷり24時間リレー生放送！\nたくさんのご視聴もコメントもありがとうございました。\n私も密かに監視しておりましたよ。。。\nふふふ。。。\n\n昨日は、まさか自分が放送に出るとは思ってもいませんでした…。\nかなり緊張しました。本当に緊張しました。\n人生で一番、名前を呼ばれた気がします。\n\n初のブログ、初の放送…。初の似顔絵…。\nこの歳になっても、まだまだ人生初の出来事がたくさんあるものだなと感じる１日でした。\n\nそして…！人',
#     'separator': None,
#     'isLimited': False,
#     'isTrial': False,
#     'canUpdate': False,
#     'tweetText': 'あらためまして、菊「地」です。｜株式会社STPR #note',
#     'additionalAttr': {'anonymousLikeCount': 10110},
#     'isRefund': False,
#     'likeCount': 13147},
#    {'id': 15252445,
#     'type': 'TextNote',
#     'status': 'published',
#     'name': '感謝、感激。株式会社STPR 菊地です。',
#     'description': None,
#     'price': 0,
#     'key': 'na4d046982bb9',
#     'slug': 'slug-na4d046982bb9',
#     'publishAt': '2020/05/09 19:02',
#     'thumbnailExternalUrl': '',
#     'eyecatch': 'https://assets.st-note.com/production/uploads/images/25124300/square_large_13c194c9301fe1ab5b62e933199a7e34.jpg',
#     'user': {'id': 2813483,
#      'name': '株式会社STPR',
#      'urlname': 'stpr',
#      'nickname': '株式会社STPR',
#      'userProfileImagePath': 'https://assets.st-note.com/production/uploads/images/28264468/profile_4717624ff99ea691533a916772bbdf03.jpg?fit=bounds&format=jpeg&quality=45&width=330',
#      'customDomain': None,
#      'disableSupport': True,
#      'likeAppealText': None,
#      'likeAppealImage': None,
#      'purchaseAppealTextNote': None,
#      'twitterNickname': None},
#     'canRead': True,
#     'isAuthor': False,
#     'externalUrl': None,
#     'customDomain': None,
#     'body': 'みなさん、こんばんは。\n株式会社STPRの菊地です。\n\n今年のゴールデンウィークは例年になく、みなさんおうちにいる時間が多いと思いますが、いかがお過ごしでしょうか？\n私は変わらず粛々とおうちでお仕事をしています。\n\n午後ティーではなく、トロピカーナのオレンジ（栄養機能食品）…。\nもとは、さとみくんに用意していたものの、最近はあまり飲んでいないな…と、こっそりチェックしていたシリーズですが、まさか今度は、ななもり。さんからその名前がでるとは…。\nいつでもななもり。さんが飲めるよ',
#     'separator': None,
#     'isLimited': False,
#     'isTrial': False,
#     'canUpdate': False,
#     'tweetText': '感謝、感激。株式会社STPR 菊地です。｜株式会社STPR #note',
#     'additionalAttr': {'anonymousLikeCount': 10311},
#     'isRefund': False,
#     'likeCount': 13093},
#    {'id': 14001747,
#     'type': 'TextNote',
#     'status': 'published',
#     'name': '安倍総理の星野源さんコラボは何が問題だったのか / 音楽家からの視点と分析',
#     'description': None,
#     'price': 0,
#     'key': 'n094582efcd8d',
#     'slug': 'slug-n094582efcd8d',
#     'publishAt': '2020/04/13 02:17',
#     'thumbnailExternalUrl': '',
#     'eyecatch': 'https://assets.st-note.com/production/uploads/images/22825319/square_large_5fdc1be2bbb9e5ebafa8219d6f5c41b1.png',
#     'user': {'id': 2669092,
#      'name': 'KX',
#      'urlname': 'kaixaoki',
#      'nickname': 'KX',
#      'userProfileImagePath': 'https://d2l930y2yx77uc.cloudfront.net/assets/default/default_profile_3-d1242380c9f3a4409c40fcf9d224c36c964724a26248ce3bdc701227cb8f5a07.png',
#      'customDomain': None,
#      'disableSupport': False,
#      'likeAppealText': None,
#      'likeAppealImage': None,
#      'purchaseAppealTextNote': None,
#      'twitterNickname': 'kaixaoki'},
#     'canRead': True,
#     'isAuthor': False,
#     'externalUrl': None,
#     'customDomain': None,
#     'body': '星野源さんの「うちで踊ろう」を安倍総理が利用した件について、タイムラインで様々な意見が出ました。批判についてもネットメディアで取り上げられていますが、少し見当違いなものが多いように感じています。\n\n私はセミプロのジャズ・ピアニスト/作曲家として活動しており、本業でも音楽に関わる仕事をしています。あの動画がアップロードされた時、身の回りのアーティストの方々が、今まで見たことも無いような怒りをあらわにしているのを目の当たりにしました。私自身も普段は温厚な人間だと自負していますが、',
#     'separator': None,
#     'isLimited': False,
#     'isTrial': False,
#     'canUpdate': False,
#     'tweetText': '安倍総理の星野源さんコラボは何が問題だったのか / 音楽家からの視点と分析｜KX @kaixaoki #note',
#     'additionalAttr': {'anonymousLikeCount': 9788,
#      'index': [{'name': '50RyB', 'body': '１．安倍さんが嫌いな方々'},
#       {'name': 'deS7Z', 'body': '２．家にいたくてもいることのできない方々'},
#       {'name': '8Sejd', 'body': '３．音楽家'},
#       {'name': 'Rd8gE', 'body': 'まとめ'}]},
#     'isRefund': False,
#     'likeCount': 12526},
#    {'id': 22448802,
#     'type': 'TextNote',
#     'status': 'published',
#     'name': '凡人が、天才に勝つ方法。',
#     'description': None,
#     'price': 0,
#     'key': 'n22972c7216d4',
#     'slug': 'slug-n22972c7216d4',
#     'publishAt': '2020/10/21 17:54',
#     'thumbnailExternalUrl': '',
#     'eyecatch': 'https://assets.st-note.com/production/uploads/images/37154525/square_large_ede411a1fd5cafe659e0c7f91f9c622b.jpg',
#     'user': {'id': 3411903,
#      'name': 'つんく♂',
#      'urlname': 'tsunkuboy',
#      'nickname': 'つんく♂',
#      'userProfileImagePath': 'https://assets.st-note.com/production/uploads/images/36181120/profile_e0e9b1328d6f6d524bb471b5101d1f4a.jpg?fit=bounds&format=jpeg&quality=45&width=330',
#      'customDomain': {'id': 911,
#       'tls': True,
#       'host': 'note.tsunku.net',
#       'type': 'creator',
#       'key': 'tsunkuboy'},
#      'disableSupport': False,
#      'likeAppealText': 'お！「スキ」あざーす！',
#      'likeAppealImage': 'https://assets.st-note.com/production/uploads/images/36746053/63fa49e700f1fe3ac0f7feb404fc5cde.png?fit=bounds&format=jpeg&height=500&quality=45&width=500',
#      'purchaseAppealTextNote': '読んでくれてありがとうございます。\nここを気に入ったらお友達にも紹介してください！\n次を楽しみしててください！がんばります！',
#      'twitterNickname': 'tsunkuboy'},
#     'canRead': True,
#     'isAuthor': False,
#     'externalUrl': None,
#     'customDomain': {'id': 911,
#      'tls': True,
#      'host': 'note.tsunku.net',
#      'type': 'creator',
#      'key': 'tsunkuboy'},
#     'body': 'はじめまして、どうも、つんく♂です。\n\n作詞・作曲を中心に音楽やエンタメ全般のプロデューサーをやっています。モーニング娘。のプロデュースから始めて、アイドルやアーティストなど、たくさんの作品を生み出してきました。\n\n『リズム天国』などのゲームや、アニメにも関わっています。今は、「つんく♂エンタメ♪サロン」のメンバーで、「中2」をテーマにした映画制作を始めたばかりです。\n\n声の病気をしたので今は歌えませんが、その分、日々の作品作りと、次世代のスターやクリエイターの応援に注力して',
#     'separator': None,
#     'isLimited': False,
#     'isTrial': False,
#     'canUpdate': False,
#     'tweetText': '凡人が、天才に勝つ方法。｜つんく♂ @tsunkuboy #つんくnote #プロデューサー視点 #私の仕事',
#     'additionalAttr': {'anonymousLikeCount': 4603},
#     'isRefund': False,
#     'likeCount': 11696},
#    {'id': 10525606,
#     'type': 'TextNote',
#     'status': 'published',
#     'name': '’89 牧瀬里穂のJR東海クリスマスエクスプレスのCMが良すぎて書き殴ってしまった',
#     'description': None,
#     'price': 0,
#     'key': 'na01d6800ba12',
#     'slug': 'slug-na01d6800ba12',
#     'publishAt': '2019/12/17 11:59',
#     'thumbnailExternalUrl': '',
#     'eyecatch': None,
#     'user': {'id': 335214,
#      'name': 'pato',
#      'urlname': 'pato_numeri',
#      'nickname': 'pato',
#      'userProfileImagePath': 'https://assets.st-note.com/production/uploads/images/949535/profile_46488067899120b2f68d611fd8f9e4e8.jpg?fit=bounds&format=jpeg&quality=45&width=330',
#      'customDomain': None,
#      'disableSupport': True,
#      'likeAppealText': None,
#      'likeAppealImage': None,
#      'purchaseAppealTextNote': None,
#      'twitterNickname': 'pato_numeri'},
#     'canRead': True,
#     'isAuthor': False,
#     'externalUrl': None,
#     'customDomain': None,
#     'body': 'ここにあった文章はすったもんだの末、https://sakumaga.sakura.ad.jp/entry/2020/10/07/120000\n\nに移動しました',
#     'separator': None,
#     'isLimited': False,
#     'isTrial': False,
#     'canUpdate': False,
#     'tweetText': '’89 牧瀬里穂のJR東海クリスマスエクスプレスのCMが良すぎて書き殴ってしまった｜pato @pato_numeri #note',
#     'additionalAttr': {'anonymousLikeCount': 7452},
#     'isRefund': False,
#     'likeCount': 11663},
#    {'id': 8814619,
#     'type': 'TextNote',
#     'status': 'published',
#     'name': '「裸一貫！つづ井さん」についてちょっと真面目に話させてくんちぇ〜',
#     'description': None,
#     'price': 0,
#     'key': 'n28f73ff5cdce',
#     'slug': 'slug-n28f73ff5cdce',
#     'publishAt': '2019/09/11 18:52',
#     'thumbnailExternalUrl': '',
#     'eyecatch': None,
#     'user': {'id': 1096620,
#      'name': 'つづ井',
#      'urlname': 'happyhappylove',
#      'nickname': 'つづ井',
#      'userProfileImagePath': 'https://assets.st-note.com/production/uploads/images/14291917/profile_d96fc235f4a03fcab1a6d5be7f890849.jpeg?fit=bounds&format=jpeg&quality=45&width=330',
#      'customDomain': None,
#      'disableSupport': False,
#      'likeAppealText': None,
#      'likeAppealImage': None,
#      'purchaseAppealTextNote': None,
#      'twitterNickname': None},
#     'canRead': True,
#     'isAuthor': False,
#     'externalUrl': None,
#     'customDomain': None,
#     'body': '\u3000\n\n※9月13日 ささやかに追記しました。\n\nnoteを読んで下さってありがとうございます、つづ井と申します。\nこれまで「腐女子のつづ井さん」というエッセイ漫画を、全3巻にわたり描かせていただきました。現在は、Crea Webさんで「裸一貫！つづ井さん」というタイトルで連載させていただいております。\nそして、応援してくださる皆様のおかげで、「裸一貫！つづ井さん」の方も本日9月11日にコミックスが発売となりました。改めてお礼申し上げます。いつもありがとうございます！\n\n\u3000この',
#     'separator': None,
#     'isLimited': False,
#     'isTrial': False,
#     'canUpdate': False,
#     'tweetText': '「裸一貫！つづ井さん」についてちょっと真面目に話させてくんちぇ〜｜つづ井 #note',
#     'additionalAttr': {'anonymousLikeCount': 7443},
#     'isRefund': False,
#     'likeCount': 11476},
#    {'id': 20043057,
#     'type': 'TextNote',
#     'status': 'published',
#     'name': '将棋ファンがなぜ藤井聡太にこれほど熱狂するのか、将棋ファン自身がわかりやすく解説してみた',
#     'description': None,
#     'price': 0,
#     'key': 'n8dcfe6d1ce49',
#     'slug': 'slug-n8dcfe6d1ce49',
#     'publishAt': '2020/08/25 15:59',
#     'thumbnailExternalUrl': '',
#     'eyecatch': 'https://assets.st-note.com/production/uploads/images/33264418/square_large_4d738af0fee59cdb0080abe06bf9b66c.jpg',
#     'user': {'id': 2215664,
#      'name': 'ながいふうか',
#      'urlname': 'nagaifuuka',
#      'nickname': 'ながいふうか',
#      'userProfileImagePath': 'https://assets.st-note.com/production/uploads/images/34552644/profile_81ba57cbd4470619a80b1074b29bdfb8.jpg?fit=bounds&format=jpeg&quality=45&width=330',
#      'customDomain': None,
#      'disableSupport': False,
#      'likeAppealText': None,
#      'likeAppealImage': None,
#      'purchaseAppealTextNote': None,
#      'twitterNickname': None},
#     'canRead': True,
#     'isAuthor': False,
#     'externalUrl': None,
#     'customDomain': None,
#     'body': '――棋士とAIの対決をどう思われますか？\n\u3000将棋ソフトとの対局は大きな話題になりましたけど、将棋ソフトと対決の時代をこえて、共存という時代に入ったのかなと思います。\n\u3000プレイヤーとしては、ソフトを活用することで、自分自身成長できる可能性があると思っていますし、見ていただく方も、観戦の際の、楽しみの一つにしていただければと思います。今の時代においても、将棋界の盤上の物語は不変のものと思いますし、その価値を自分自身伝えられたらなと思います。\n\n\u3000上記は藤井聡太（現）二冠が初めて棋',
#     'separator': None,
#     'isLimited': False,
#     'isTrial': False,
#     'canUpdate': False,
#     'tweetText': '将棋ファンがなぜ藤井聡太にこれほど熱狂するのか、将棋ファン自身がわかりやすく解説してみた｜ながいふうか #note #自己紹介',
#     'additionalAttr': {'anonymousLikeCount': 7008},
#     'isRefund': False,
#     'likeCount': 11248},
#    {'id': 13611490,
#     'type': 'TextNote',
#     'status': 'published',
#     'name': '0403「NY感染体験記（確定）」',
#     'description': None,
#     'price': 0,
#     'key': 'na170878156cc',
#     'slug': 'slug-na170878156cc',
#     'publishAt': '2020/04/03 07:16',
#     'thumbnailExternalUrl': '',
#     'eyecatch': 'https://assets.st-note.com/production/uploads/images/22094019/square_large_9f7f5fd60179aceb2f02790303d5d8fd.png',
#     'user': {'id': 1213493,
#      'name': 'qanta',
#      'urlname': 'qantasmz',
#      'nickname': 'qanta',
#      'userProfileImagePath': 'https://assets.st-note.com/production/uploads/images/8699233/profile_b0590e4269f6da4e1d7c36b28f78c7db.jpg?fit=bounds&format=jpeg&quality=45&width=330',
#      'customDomain': None,
#      'disableSupport': True,
#      'likeAppealText': None,
#      'likeAppealImage': None,
#      'purchaseAppealTextNote': None,
#      'twitterNickname': 'qanta'},
#     'canRead': True,
#     'isAuthor': False,
#     'externalUrl': None,
#     'customDomain': None,
#     'body': '【5/7抗体検査陽性・感染確定・文末に追記あり】\n\n「NY非常事態日報」と銘打って非常事態下のニューヨークについてレポートしよう、ということで文章を書いていたのが３月17日から19日までの３日間。無観客開催となった大相撲春場所も後半に差し掛かる頃だった。この段階ではまだ外出禁止令的なことにはなっておらず、しかし数日中にそういう状態になるだろうと言われているくらいのタイミングだった。\n\n3/19時点でのニューヨーク市（州ではなく、市）の感染者数は1,871名。学校はすべて休校に',
#     'separator': None,
#     'isLimited': False,
#     'isTrial': False,
#     'canUpdate': False,
#     'tweetText': '0403「NY感染体験記（確定）」｜qanta @qanta #note',
#     'additionalAttr': {'anonymousLikeCount': 7384,
#      'index': [{'name': '33sd3', 'body': '発症'},
#       {'name': '2VqTN', 'body': '風邪系の症状'},
#       {'name': 'm7c6g', 'body': '臭覚・味覚の喪失'},
#       {'name': '8Ej6g', 'body': '呼吸困難'},
#       {'name': 'vkIMW', 'body': 'その他。恐怖とか社会とか。'},
#       {'name': 'cWzeD', 'body': '抗体検査・5/7'}]},
#     'isRefund': False,
#     'likeCount': 11234}],
#   'topSearchContents': [],
#   'isLastPage': False,
#   'totalCount': 100000}}

# %%
name = data.json()['data']['contents'][0]['name']
key = data.json()['data']['contents'][0]['key'] 
len(data.json()['data']['contents'])
# Out:
# 20

# %%
def main():
    USER_ID = info['USER_ID']
    messages = TextSendMessage(text='おっはモーニング\nオススメの動画だよ～\nhttps://www.youtube.com/watch?v=cNmkXj8aKOU')
    line_bot_api.push_message(USER_ID,messages=messages)
    
if __name__ == "__main__":
    main()
